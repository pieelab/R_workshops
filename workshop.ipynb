# %%
library(data.table)

# %% [markdown]
# # Why `data.table`
#
#
# ## Why `R`
#
#
# ## An improved data.frame
#
# * Syntax
# * Performance
# * Conpectual improvements (key, joins, ...)

# %% [markdown]
# # The data
# Some description of our data

# %%
# dt <- fread("some_url")
dt <- data.table(a=rnorm(1000), b=1:1000)
dt
# Out:
#      a            b
# 1    -0.09726908   1
# 2    -1.01066205   2
# 3     1.00561859   3
# 4    -0.58245372   4
# 5    -1.06730271   5
# 6     0.28394880   6
# 7     0.81448884   7
# 8     0.03609655   8
# 9     2.36508469   9
# 10   -0.83438544  10
# 11   -0.33216681  11
# 12    0.87371098  12
# 13    0.74025165  13
# 14    0.52298459  14
# 15   -1.38194713  15
# 16   -0.70342893  16
# 17    0.75178610  17
# 18   -0.50471946  18
# 19    0.43984279  19
# 20    0.04145109  20
# 21    0.63997383  21
# 22   -0.61977466  22
# 23    1.58140278  23
# 24    0.32203770  24
# 25   -0.11824700  25
# 26    0.59307212  26
# 27   -0.71460584  27
# 28   -1.08629096  28
# 29    1.81084127  29
# 30   -0.85614199  30
# ⋮    ⋮            ⋮
# 971   0.748203340  971
# 972   1.108387953  972
# 973  -0.599540281  973
# 974  -0.315034717  974
# 975   1.202559684  975
# 976  -2.273118832  976
# 977   1.387671192  977
# 978  -0.397616720  978
# 979  -0.759757515  979
# 980  -0.795746880  980
# ...
